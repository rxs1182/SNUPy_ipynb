# %% [markdown]
# # Rachel EDA Notebook

# %% [markdown]
# ## Imports

# %%
import pandas
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Data Extraction
# using an appropriate library(s) read the following csv files from the data folder and show the dataframes:
#   - atlanta_batting.csv
#   - atlanta_pitching.csv
#   - angels_batting.csv
#   - angels_pitching.csv

# %%
atlanta_batting = pandas.read_csv("atlanta_batting.csv").dropna()
atlanta_pitching = pandas.read_csv("atlanta_pitching.csv")
angels_batting = pandas.read_csv("angels_batting.csv")
angels_pitching = pandas.read_csv("angels_pitching.csv")

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### Win Percentage
# Using the pandas library explore all 4 datasets and add an additional column for win percentage.

# %%
atlanta_batting["WIN%"] = atlanta_batting["W"] / (atlanta_batting["W"] + atlanta_batting["L"])
atlanta_pitching["WIN%"] = atlanta_pitching["W"] / (atlanta_pitching["W"] + atlanta_pitching["L"])
angels_batting["WIN%"] = angels_batting["W"] / (angels_batting["W"] + angels_batting["L"])
angels_pitching["WIN%"] = angels_pitching["W"] / (angels_pitching["W"] + angels_pitching["L"])

# %% [markdown]
# ### Best Pitching Seasons
# Using the pandas library make a sub-dataframe to obtain the pitching stats that both teams had in their top 10 seasons based on win %age

# %%
top_tens_pitches = pandas.concat([atlanta_pitching.nlargest(10, "WIN%"), angels_pitching.nlargest(10, "WIN%")])
top_tens_pitches
# Out:
#      Year       Lg    W   L  Finish  RA/G   ERA    G    CG  tSho  ...    BB  \
# 126  1897       NL   93  39       1  4.93  3.65  135  0.85  0.06  ...  2.91
# 146  1877       NL   42  18       1  4.31  2.15   61  1.00  0.11  ...  0.62
# 125  1898       NL  102  47       1  4.04  2.98  152  0.84  0.06  ...  3.09
# 145  1878       NL   41  19       1  4.02  2.32   60  0.97  0.15  ...  0.63
# 131  1892       NL  102  48       1  4.27  2.86  152  0.93  0.10  ...  3.03
# 130  1893       NL   86  43       1  6.07  4.43  131  0.87  0.02  ...  3.07
# 139  1884       NL   73  38       2  4.03  2.47  116  0.94  0.12  ...  1.16
# 25   1998  NL East  106  56       1  3.59  3.25  162  0.15  0.14  ...  2.88
# 0    2023  NL East   50  27       1  4.17  3.85   77  0.01  0.06  ...  3.23
# 134  1889       NL   83  45       2  4.71  3.36  133  0.91  0.08  ...  3.11
# 15   2008  AL West  100  62       1  4.30  3.99  162  0.04  0.06  ...  2.82
# ...

# %% [markdown]
# ### Best Batting Seasons
# Using the pandas library make a sub-dataframe to obtain the batting stats that both teams had in their top 10 seasons based on win %age

# %%
top_tens_bats = pandas.concat([atlanta_batting.nlargest(10, "WIN%"), angels_batting.nlargest(10, "WIN%")])
top_tens_bats
# Out:
#     Year       Lg    W   L  Finish    G    PA     AB     R     H  ...    BB  \
# 25  1998  NL East  106  56       1  162  38.4  33.85  5.10  9.19  ...  3.38
# 0   2023  NL East   50  27       1   77  38.4  34.35  5.56  9.30  ...  3.45
# 30  1993  NL West  104  58       1  162  38.5  34.04  4.73  8.91  ...  3.46
# 24  1999  NL East  103  59       1  162  39.2  34.38  5.19  9.14  ...  3.75
# 21  2002  NL East  101  59       1  161  38.7  34.13  4.40  8.87  ...  3.47
# 28  1995  NL East   90  54       1  144  37.9  33.43  4.48  8.35  ...  3.61
# 1   2022  NL East  101  61       1  162  37.5  34.01  4.87  8.60  ...  2.90
# 20  2003  NL East  101  61       1  162  39.4  35.00  5.60  9.93  ...  3.36
# 26  1997  NL East  101  61       1  162  39.0  34.12  4.88  9.20  ...  3.69
# 66  1957       NL   95  59       1  155  39.0  35.21  4.98  9.48  ...  2.97
# 15  2008  AL West  100  62       1  162  38.0  34.20  4.72  9.17  ...  2.97
# ...

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### Atlanta Win Prediction using batting stats
# Train a model to predict the Win %age of a season for the braves using their batting stats

# %%
x = atlanta_batting.iloc[:,-22:-1].to_numpy()
y = atlanta_batting["WIN%"].to_numpy().reshape(-1, 1)

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.35)
linearline = LinearRegression()
linearline.fit(x_train,y_train)
linearline.score(x_test, y_test)
# Out:
# 0.8187366662849521

# %% [markdown]
# ### Atlanta Win Prediction using pitching stats
# Train a model to predict the Win %age of a season for the braves using their pitching stats

# %%
x = angels_pitching.iloc[:,-22:-1].to_numpy()
y = angels_pitching["WIN%"].to_numpy().reshape(-1, 1)
x
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.35)
linearline = LinearRegression()
linearline.fit(x_train,y_train)
linearline.score(x_test, y_test)
# Out:
# 0.6076263742602306

# %% [markdown]
# ### Angles Win Prediction using batting stats
# Train a model to predict the Win %age of a season for the angels using their batting stats

# %%
x = angels_batting.iloc[:,-22:-1].to_numpy()
y = angels_batting["WIN%"].to_numpy().reshape(-1, 1)

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.35)
linearline = LinearRegression()
linearline.fit(x_train,y_train)
linearline.score(x_test, y_test)
# Out:
# 0.24419720497792496

# %% [markdown]
# ### Angles Win Prediction using batting stats
# Train a model to predict the Win %age of a season for the angels using their batting stats

# %%
x = angels_pitching.iloc[:,-22:-1].to_numpy()
y = angels_pitching["WIN%"].to_numpy().reshape(-1, 1)

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.35)
linearline = LinearRegression()
linearline.fit(x_train,y_train)
linearline.score(x_test, y_test)
# Out:
# -5.070666689500129

# %% [markdown]
# ## Advanced EDA

# %% [markdown]
# ### Fine Tuned Atlanta Batting Model
# Find the 3 most important features amongst the batting stats for accurate prediction of the win %age for the Atlanta Braves

# %%
x = atlanta_batting.iloc[:,-22:-1]
y = atlanta_batting["WIN%"].to_numpy().reshape(-1, 1)
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.35)

model = LinearRegression()
model.fit(x_train, y_train)
importances = pandas.DataFrame(data={
    'Attribute': x_train.columns,
    'Importance': model.coef_[0]
})
importances = importances.sort_values(by='Importance', ascending=False)
importances[0:3]
# Out:
#    Attribute  Importance
# 20      Fld%   23.554430
# 15       OBP    4.996623
# 14        BA    3.749608

# %% [markdown]
# ### Fine Tuned Atlanta Pitching Model
# Find the 3 most important features amongst the pitching stats for accurate prediction of the win %age for the Atlanta Braves

# %%
x = atlanta_pitching.iloc[:,-22:-1]
y = atlanta_pitching["WIN%"].to_numpy().reshape(-1, 1)
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.35)

model = LinearRegression()
model.fit(x_train, y_train)
importances = pandas.DataFrame(data={
    'Attribute': x_train.columns,
    'Importance': model.coef_[0]
})
importances = importances.sort_values(by='Importance', ascending=False)
importances[0:3]
# Out:
#    Attribute  Importance
# 16       HR9    1.776437
# 5       tSho    0.435277
# 6         SV    0.281667

# %% [markdown]
# ### Fine Tuned Angels Batting Model
# Find the 3 most important features amongst the batting stats for accurate prediction of the win %age for the Angels

# %%
x = angels_batting.iloc[:,-22:-1]
y = angels_batting["WIN%"].to_numpy().reshape(-1, 1)
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.35)

model = LinearRegression()
model.fit(x_train, y_train)
importances = pandas.DataFrame(data={
    'Attribute': x_train.columns,
    'Importance': model.coef_[0]
})
importances = importances.sort_values(by='Importance', ascending=False)
importances[0:3]
# Out:
#    Attribute  Importance
# 20      Fld%   27.020417
# 16       SLG    4.171351
# 17       OPS    1.557908

# %% [markdown]
# ### Fine Tuned Angels Pitching Model
# Find the 3 most important features amongst the pitching stats for accurate prediction of the win %age for the Angels

# %%
x = angels_pitching.iloc[:,-22:-1]
y = angels_pitching["WIN%"].to_numpy().reshape(-1, 1)
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.35)

model = LinearRegression()
model.fit(x_train, y_train)
importances = pandas.DataFrame(data={
    'Attribute': x_train.columns,
    'Importance': model.coef_[0]
})
importances = importances.sort_values(by='Importance', ascending=False)
importances[0:3]
# Out:
#    Attribute  Importance
# 19      Fld%   11.102245
# 14      WHIP    3.290547
# 11        HR    0.956453
