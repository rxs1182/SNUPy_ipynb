# %% [markdown]
# # PyTorch EDA
# ## Author: Rohan Singh
# In this notebook we will undertake some EDA (Exploratory Data Analysis) of a wine quality dataset the same way one would do it with numpy, pandas and matplotlib.

# %% [markdown]
# ## Libraries Used

# %%
# Data Loading 
import requests
import pandas as pd

# PyTorch libraries
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
torch.set_printoptions(edgeitems=2)
torch.manual_seed(123)
from torchvision import models
from torchvision import transforms

# %% [markdown]
# ## Data Loading

# %%
req = requests.get("https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv")
content = req.content

file = open('wine.csv','wb')
file.write(content)
file.close()

# %%
df = pd.read_csv("wine.csv",delimiter=";")

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...
